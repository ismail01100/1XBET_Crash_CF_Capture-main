# %%
import pandas as pd


df=pd.read_csv('data.csv',header=None)
df.head()
# Out:
#         0               1                       2                    3  \
# 0  Round1  Time: 19:15:45  NumberOfPlayers: 12369  TotalBet: 217058.19
# 1  Round2  Time: 19:17:31  NumberOfPlayers: 12553  TotalBet: 224750.88
# 2  Round3  Time: 19:17:49  NumberOfPlayers: 10892  TotalBet: 203106.63
# 3  Round4  Time: 19:18:07   NumberOfPlayers: 9862  TotalBet: 182495.56
# 4  Round5  Time: 19:18:30  NumberOfPlayers: 11344  TotalBet: 209669.43
#
#                          4             5
# 0  TotalWinning: 132006.59   OnCash: 2.5
# 1    TotalWinning: 7298.76  OnCash: 1.23
# 2    TotalWinning: 3825.73  OnCash: 1.12
# 3   TotalWinning: 67343.15  OnCash: 2.37
# 4   TotalWinning: 283202.9  OnCash: 3.57

# %%
df.columns=['Round', 'Time', 'Numberofplayers', 'totalbet', 'totalwinning', 'onCash']

# %%
df.head()
# Out:
#     Round            Time         Numberofplayers             totalbet  \
# 0  Round1  Time: 19:15:45  NumberOfPlayers: 12369  TotalBet: 217058.19
# 1  Round2  Time: 19:17:31  NumberOfPlayers: 12553  TotalBet: 224750.88
# 2  Round3  Time: 19:17:49  NumberOfPlayers: 10892  TotalBet: 203106.63
# 3  Round4  Time: 19:18:07   NumberOfPlayers: 9862  TotalBet: 182495.56
# 4  Round5  Time: 19:18:30  NumberOfPlayers: 11344  TotalBet: 209669.43
#
#               totalwinning        onCash
# 0  TotalWinning: 132006.59   OnCash: 2.5
# 1    TotalWinning: 7298.76  OnCash: 1.23
# 2    TotalWinning: 3825.73  OnCash: 1.12
# 3   TotalWinning: 67343.15  OnCash: 2.37
# 4   TotalWinning: 283202.9  OnCash: 3.57

# %%
df.dtypes
# Out:
# Round              object
# Time               object
# Numberofplayers    object
# totalbet           object
# totalwinning       object
# onCash             object
# dtype: object

# %%
df['Round']=df['Round'].map(lambda x: x[-1])

# %%
df.head()
# Out:
#   Round            Time         Numberofplayers             totalbet  \
# 0     1  Time: 19:15:45  NumberOfPlayers: 12369  TotalBet: 217058.19
# 1     2  Time: 19:17:31  NumberOfPlayers: 12553  TotalBet: 224750.88
# 2     3  Time: 19:17:49  NumberOfPlayers: 10892  TotalBet: 203106.63
# 3     4  Time: 19:18:07   NumberOfPlayers: 9862  TotalBet: 182495.56
# 4     5  Time: 19:18:30  NumberOfPlayers: 11344  TotalBet: 209669.43
#
#               totalwinning        onCash
# 0  TotalWinning: 132006.59   OnCash: 2.5
# 1    TotalWinning: 7298.76  OnCash: 1.23
# 2    TotalWinning: 3825.73  OnCash: 1.12
# 3   TotalWinning: 67343.15  OnCash: 2.37
# 4   TotalWinning: 283202.9  OnCash: 3.57

# %%
print('ok') if 5 > 4 else print('no')
# Out:
# ok

# %%
import numpy as np

# %%
True and (device:='cuda') or (device:='cpu')
# Out:
# 'cuda'

# %%
df['Time']=df['Time'].map(lambda x: x[len('time: '):])
df['Numberofplayers']=df['Numberofplayers'].map(lambda x: x[len('Numberofplayers: '):])
df['totalbet']=df['totalbet'].map(lambda x: x[len('totalbet: '):])
df['totalwinning']=df['totalwinning'].map(lambda x: x[len('totalwinning: '):])
df['onCash']=df['onCash'].map(lambda x: x[len('onCash: '):])

# %%
df.head()
# Out:
#   Round      Time Numberofplayers   totalbet totalwinning onCash
# 0     1  19:15:45           12369  217058.19    132006.59    2.5
# 1     2  19:17:31           12553  224750.88      7298.76   1.23
# 2     3  19:17:49           10892  203106.63      3825.73   1.12
# 3     4  19:18:07            9862  182495.56     67343.15   2.37
# 4     5  19:18:30           11344  209669.43     283202.9   3.57

# %%
for i in df.columns:
    if i=='Time':
        continue
    df[i]=df[i].astype(np.float32)

# %%
df.dtypes
# Out:
# Round              float32
# Time                object
# Numberofplayers    float32
# totalbet           float32
# totalwinning       float32
# onCash             float32
# dtype: object

# %%
df.head()
# Out:
#    Round      Time  Numberofplayers     totalbet   totalwinning  onCash
# 0    1.0  19:15:45          12369.0  217058.1875  132006.593750    2.50
# 1    2.0  19:17:31          12553.0  224750.8750    7298.759766    1.23
# 2    3.0  19:17:49          10892.0  203106.6250    3825.729980    1.12
# 3    4.0  19:18:07           9862.0  182495.5625   67343.148438    2.37
# 4    5.0  19:18:30          11344.0  209669.4375  283202.906250    3.57

# %%
df.where(df['Time']=='0').dropna()
# Out:
#        Round Time  Numberofplayers       totalbet   totalwinning     onCash
# 2317     8.0    0           6773.0       0.000000  550972.250000  21.790001
# 14713    7.0    0           5803.0  133471.250000  386085.875000  17.990000
# 14847    1.0    0           6092.0   10719.419922  224198.156250   4.260000
# 15040    4.0    0           5146.0   50653.921875  265926.156250   7.330000
# 15649    3.0    0           6008.0  108677.078125   53776.828125   1.370000
# 16878    2.0    0           6723.0  114066.062500  307500.687500  21.250000
# 18318    2.0    0           5837.0  118558.820312  482377.062500  28.690001
# 18480    3.0    0           4434.0   48126.570312  420905.218750  21.490000
# 22269    3.0    0           2870.0   69408.203125   21028.580078   1.010000
# 24918    3.0    0           8147.0  107219.312500   43763.011719   2.180000
# 26115    1.0    0           7805.0       0.000000  110265.531250   2.610000

# %%
df.where(df['Time']=='0').dropna().index
# Out:
# Index([2317, 14713, 14847, 15040, 15649, 16878, 18318, 18480, 22269, 24918,
#        26115],
#       dtype='int64')

# %%
for i in df.where(df['Time']=='0').dropna().index:
    df.drop(i,inplace=True)

# %%
df.where(df['Time']=='0').dropna()
# Out:
# Empty DataFrame
# Columns: [Round, Time, Numberofplayers, totalbet, totalwinning, onCash]
# Index: []

# %%
for i in df.where(df['Numberofplayers']=='0').dropna().index:
    df.drop(i,inplace=True)

# %%
'19:15:45'.split(':')
# Out:
# ['19', '15', '45']

# %%
df.where(df['Numberofplayers']=='0').dropna()
# Out:
# Empty DataFrame
# Columns: [Round, Time, Numberofplayers, totalbet, totalwinning, onCash]
# Index: []

# %%
df['hour']=df['Time'].map(lambda x: x.split(':')[0])
df['minutes']=df['Time'].map(lambda x: x.split(':')[1])
df['seconds']=df['Time'].map(lambda x: x.split(':')[2])

# %%
df.drop(['Time'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Round  Numberofplayers     totalbet   totalwinning  onCash hour minutes  \
# 0    1.0          12369.0  217058.1875  132006.593750    2.50   19      15
# 1    2.0          12553.0  224750.8750    7298.759766    1.23   19      17
# 2    3.0          10892.0  203106.6250    3825.729980    1.12   19      17
# 3    4.0           9862.0  182495.5625   67343.148438    2.37   19      18
# 4    5.0          11344.0  209669.4375  283202.906250    3.57   19      18
#
#   seconds
# 0      45
# 1      31
# 2      49
# 3      07
# 4      30

# %%
for i in df.columns:
    df[i]=df[i].astype(np.float32)

# %%
df.dtypes
# Out:
# Round              float32
# Numberofplayers    float32
# totalbet           float32
# totalwinning       float32
# onCash             float32
# hour               float32
# minutes            float32
# seconds            float32
# dtype: object

# %%
df.head()
# Out:
#    Round  Numberofplayers     totalbet   totalwinning  onCash  hour  minutes  \
# 0    1.0          12369.0  217058.1875  132006.593750    2.50  19.0     15.0
# 1    2.0          12553.0  224750.8750    7298.759766    1.23  19.0     17.0
# 2    3.0          10892.0  203106.6250    3825.729980    1.12  19.0     17.0
# 3    4.0           9862.0  182495.5625   67343.148438    2.37  19.0     18.0
# 4    5.0          11344.0  209669.4375  283202.906250    3.57  19.0     18.0
#
#    seconds
# 0     45.0
# 1     31.0
# 2     49.0
# 3      7.0
# 4     30.0

# %%
X=df.drop(['onCash'],axis=1)
Y=df['onCash']

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from xgboost import XGBRegressor

# Initialize the XGBRegressor
model = XGBRegressor(
    objective='reg:squarederror',  # for regression
    max_depth=4,
    eta=0.1,
    n_estimators=100
)

# Train the model
model.fit(x_train, y_train)

# Make predictions
preds = model.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, preds)
mae = mean_absolute_error(y_test, preds)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, preds)
mape = np.mean(np.abs((y_test - preds) / y_test)) * 100

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}%")

# Optionally, save the model
model.save_model('xgboost_regression_model.json')
# Out:
# Mean Squared Error (MSE): 5.854693412780762
# Mean Absolute Error (MAE): 0.9348006844520569
# Root Mean Squared Error (RMSE): 2.419647455215454
# R-squared (R²): 0.8140156363258897
# Mean Absolute Percentage Error (MAPE): 23.866087198257446%

# %%
preds = model.predict([[1.0,12369.0,217058.1875,132006.593750,19.0,15.0,45.0]])

preds
# Out:
# array([2.413892], dtype=float32)

# %%
model = XGBRegressor()
model.load_model('xgboost_regression_model.json')


preds = model.predict([[1.0,12369.0,217058.1875,132006.593750,19.0,15.0,45.0]])

preds.item()
# Out:
# 2.4138920307159424

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score



# Create LightGBM Dataset
train_data = lgb.Dataset(x_train, label=y_train)
test_data = lgb.Dataset(x_test, label=y_test, reference=train_data)

# Set parameters for LightGBM
params = {
    'objective': 'regression',
    'metric': 'l2',  # l2 for mean squared error
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.1,
    'feature_fraction': 0.9
}

# Train the model
num_rounds = 100
bst = lgb.train(params, train_data, num_rounds, valid_sets=[test_data],  callbacks=[
        lgb.early_stopping(stopping_rounds=50),
    ])

# Make predictions
preds = bst.predict(x_test, num_iteration=bst.best_iteration)

# Evaluate the model
mse = mean_squared_error(y_test, preds)
mae = mean_absolute_error(y_test, preds)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, preds)
mape = np.mean(np.abs((y_test - preds) / y_test)) * 100

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}%")

# Save the model
bst.save_model('lightgbm_regression_model.txt')
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000614 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 919
# [LightGBM] [Info] Number of data points in the train set: 20906, number of used features: 7
# [LightGBM] [Info] Start training from score 4.146120
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	valid_0's l2: 5.85545
# Mean Squared Error (MSE): 5.855448777854178
# Mean Absolute Error (MAE): 0.9257736489416712
# Root Mean Squared Error (RMSE): 2.419803458517691
# R-squared (R²): 0.8139916370846123
# Mean Absolute Percentage Error (MAPE): 24.965076661714082%

# %%
preds = bst.predict([[1.0,12369.0,217058.1875,132006.593750,19.0,15.0,45.0]])

preds
# Out:
# array([2.55723489])

# %%
bst = lgb.Booster(model_file='lightgbm_regression_model.txt')


preds = bst.predict([[1.0,12369.0,217058.1875,132006.593750,19.0,15.0,45.0]])

preds.item()
# Out:
# 2.557234890263209

# %%
model = XGBRegressor()
model.load_model('xgboost_regression_model.json')


preds1 = model.predict([[1.0,12369.0,217058.1875,132006.593750,19.0,15.0,45.0]])
bst = lgb.Booster(model_file='lightgbm_regression_model.txt')
print(preds1)

preds2 = bst.predict([[1.0,12369.0,217058.1875,132006.593750,19.0,15.0,45.0]])

print(preds2)
avg_xgboost_lgboost= (preds1.item()+preds2.item())/2

print(avg_xgboost_lgboost)
# Out:
# [2.413892]
# [2.55723489]
# 2.4855634604895758

# %%
import catboost as cb


# Initialize the CatBoostRegressor
model = cb.CatBoostRegressor(
    iterations=100,
    learning_rate=0.1,
    depth=10,
    loss_function='RMSE',
    verbose=False
)

# Train the model
model.fit(x_train, y_train)

# Make predictions
preds = model.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, preds)
mae = mean_absolute_error(y_test, preds)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, preds)
mape = np.mean(np.abs((y_test - preds) / y_test)) * 100

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}%")

# Save the model
model.save_model('catboost_regression_model.cbm')
# Out:
# Mean Squared Error (MSE): 5.804573601281116
# Mean Absolute Error (MAE): 0.9380291775410841
# Root Mean Squared Error (RMSE): 2.409268270923999
# R-squared (R²): 0.8156077742359059
# Mean Absolute Percentage Error (MAPE): 24.06775872637364%

# %%
import catboost as cb

# Load the model
model = cb.CatBoostRegressor()
model.load_model('catboost_regression_model.cbm')



# Make predictions
preds = model.predict([[1.0,12369.0,217058.1875,132006.593750,19.0,15.0,45.0]])

print(preds.item())
# Out:
# 2.4621045454028883

# %%
model_xgboost = XGBRegressor()
model_xgboost.load_model('xgboost_regression_model.json')


preds1 = model_xgboost.predict([[1.0,12369.0,217058.1875,132006.593750,19.0,15.0,45.0]])
bst = lgb.Booster(model_file='lightgbm_regression_model.txt')
print(f'prediciton of xgboost:{preds1}')

preds2 = bst.predict([[1.0,12369.0,217058.1875,132006.593750,19.0,15.0,45.0]])

print(f'prediciton of lgboost:{preds2}')

model = cb.CatBoostRegressor()
model.load_model('catboost_regression_model.cbm')



# Make predictions
preds3 = model.predict([[1.0,12369.0,217058.1875,132006.593750,19.0,15.0,45.0]])

print(f'prediciton of catboost:{preds3}')

avg_xgboost_lgboost= (preds1.item()+preds2.item())/2

print(f'avg_xgboost_lgboost:{avg_xgboost_lgboost}')


avg_lgboost_catboost= (preds2.item()+preds3.item())/2

print(f'avg_lgboost_catboost:{avg_lgboost_catboost}')
# Out:
# prediciton of xgboost:[2.413892]
# prediciton of lgboost:[2.55723489]
# prediciton of catboost:[2.46210455]
# avg_xgboost_lgboost:2.4855634604895758
# avg_lgboost_catboost:2.5096697178330487

# %%
round(avg_xgboost_lgboost,2)
# Out:
# 2.49

# %%
round(avg_lgboost_catboost,2)
# Out:
# 2.51

# %%
final_result=(round(avg_xgboost_lgboost,2)+round(avg_lgboost_catboost,2))/2

final_result
# Out:
# 2.5

# %%
def resultat(input):
    model_xgboost = XGBRegressor()
    model_xgboost.load_model('xgboost_regression_model.json')


    preds1 = model_xgboost.predict(input)
    bst = lgb.Booster(model_file='lightgbm_regression_model.txt')
    print(f'prediciton of xgboost:{preds1}')

    preds2 = bst.predict(input)

    print(f'prediciton of lgboost:{preds2}')

    model = cb.CatBoostRegressor()
    model.load_model('catboost_regression_model.cbm')



    # Make predictions
    preds3 = model.predict(input)

    print(f'prediciton of catboost:{preds3}')

    avg_xgboost_lgboost= (preds1.item()+preds2.item())/2

    print(f'avg_xgboost_lgboost:{avg_xgboost_lgboost}')


    avg_lgboost_catboost= (preds2.item()+preds3.item())/2

    print(f'avg_lgboost_catboost:{avg_lgboost_catboost}')

    return (round(avg_xgboost_lgboost,2)+round(avg_lgboost_catboost,2))/2

# %%
def resultat_nonverbose(input):
    model_xgboost = XGBRegressor()
    model_xgboost.load_model('xgboost_regression_model.json')


    preds1 = model_xgboost.predict(input)
    bst = lgb.Booster(model_file='lightgbm_regression_model.txt')
    

    preds2 = bst.predict(input)

    

    model = cb.CatBoostRegressor()
    model.load_model('catboost_regression_model.cbm')



    # Make predictions
    preds3 = model.predict(input)

    

    avg_xgboost_lgboost= (preds1.item()+preds2.item())/2

   


    avg_lgboost_catboost= (preds2.item()+preds3.item())/2

    

    return (round(avg_xgboost_lgboost,2)+round(avg_lgboost_catboost,2))/2

# %%
resultat([[1.0,12369.0,217058.1875,132006.593750,19.0,15.0,45.0]])
# Out:
# prediciton of xgboost:[2.413892]
# prediciton of lgboost:[2.55723489]
# prediciton of catboost:[2.46210455]
# avg_xgboost_lgboost:2.4855634604895758
# avg_lgboost_catboost:2.5096697178330487
# 2.5

# %%
df.head()
# Out:
#    Round  Numberofplayers     totalbet   totalwinning  onCash  hour  minutes  \
# 0    1.0          12369.0  217058.1875  132006.593750    2.50  19.0     15.0
# 1    2.0          12553.0  224750.8750    7298.759766    1.23  19.0     17.0
# 2    3.0          10892.0  203106.6250    3825.729980    1.12  19.0     17.0
# 3    4.0           9862.0  182495.5625   67343.148438    2.37  19.0     18.0
# 4    5.0          11344.0  209669.4375  283202.906250    3.57  19.0     18.0
#
#    seconds
# 0     45.0
# 1     31.0
# 2     49.0
# 3      7.0
# 4     30.0

# %%
df.head(10)
# Out:
#    Round  Numberofplayers       totalbet   totalwinning     onCash  hour  \
# 0    1.0          12369.0  217058.187500  132006.593750   2.500000  19.0
# 1    2.0          12553.0  224750.875000    7298.759766   1.230000  19.0
# 2    3.0          10892.0  203106.625000    3825.729980   1.120000  19.0
# 3    4.0           9862.0  182495.562500   67343.148438   2.370000  19.0
# 4    5.0          11344.0  209669.437500  283202.906250   3.570000  19.0
# 5    6.0          11428.0  204350.703125   41664.171875   1.720000  19.0
# 6    7.0          10393.0  186105.296875  611962.125000  21.450001  19.0
# 7    8.0          11255.0  183411.906250  343512.562500   4.540000  19.0
# 8    9.0          10291.0  166178.468750   55726.070312   1.970000  19.0
# 9    0.0           9134.0  149857.453125   68327.320312   2.040000  19.0
#
#    minutes  seconds
# 0     15.0     45.0
# 1     17.0     31.0
# 2     17.0     49.0
# 3     18.0      7.0
# 4     18.0     30.0
# 5     18.0     56.0
# ...

# %%
for i in range(10):
    print(df['onCash'][i],resultat_nonverbose([X.loc[i]]))
# Out:
# 2.5 2.5
# 1.23 1.2349999999999999
# 1.12 1.24
# 2.37 2.0549999999999997
# 3.57 3.74
# 1.72 1.7149999999999999
# 21.45 19.25
# 4.54 4.949999999999999
# 1.97 1.9249999999999998
# 2.04 2.135

# %%
df['onCash'].min()
# Out:
# 1.0

# %%
len(df)
# Out:
# 26133

# %%
import matplotlib.pyplot as plt
plt.plot(range(100),[df['onCash'][i] for i in range(100)])
plt.plot(range(100),[resultat_nonverbose([X.loc[i]]) for i in range(100)])

# %%
import matplotlib.pyplot as plt

# Assuming df and X are already defined and contain the necessary data

# Plotting the true values
plt.plot(range(100), [df['onCash'][i] for i in range(100)], label='True Values')

# Plotting the guessed values
plt.plot(range(100), [resultat_nonverbose([X.loc[i]]) for i in range(100)], label='Guessed Values')

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Comparison of True Values and Guessed Values')

# Displaying the legend
plt.legend()

# Showing the plot
plt.show()

# %%
model,model_xgboost,bst
# Out:
# (<catboost.core.CatBoostRegressor at 0x14050f150a0>,
#  XGBRegressor(base_score='4.14612E0', booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None,
#               feature_types=['float', 'float', 'float', 'float', 'float',
#                              'float', 'float'],
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...),
#  <lightgbm.basic.Booster at 0x140491efef0>)

# %%
import matplotlib.pyplot as plt

# Assuming df and X are already defined and contain the necessary data

# Plotting the true values
plt.plot(range(250), [df['onCash'][i] for i in range(250)], label='True Values')

# Plotting the guessed values
plt.plot(range(250), [resultat_nonverbose([X.loc[i]]) for i in range(250)], label='Guessed Values')

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Comparison of True Values and Guessed Values')

# Displaying the legend
plt.legend()

# Showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df and X are already defined and contain the necessary data

# Plotting the true values
plt.plot(range(250), [df['onCash'][i] for i in range(250)], label='True Values')

# Plotting the guessed values
plt.plot(range(250), [model.predict(([X.loc[i]])).item() for i in range(250)], label='Guessed Values_catboost')

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Comparison of True Values and Guessed Values')

# Displaying the legend
plt.legend()

# Showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df and X are already defined and contain the necessary data

# Plotting the true values
plt.plot(range(250), [df['onCash'][i] for i in range(250)], label='True Values')

# Plotting the guessed values
plt.plot(range(250), [model_xgboost.predict(([X.loc[i]])).item() for i in range(250)], label='Guessed Values_xgboost')

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Comparison of True Values and Guessed Values')

# Displaying the legend
plt.legend()

# Showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming df and X are already defined and contain the necessary data

# Plotting the true values
plt.plot(range(250), [df['onCash'][i] for i in range(250)], label='True Values')

# Plotting the guessed values
plt.plot(range(250), [bst.predict(([X.loc[i]])).item() for i in range(250)], label='Guessed Values_lightboost')

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Comparison of True Values and Guessed Values')

# Displaying the legend
plt.legend()

# Showing the plot
plt.show()

# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
import lightgbm as lgb
import catboost as cb

df=pd.read_csv('data.csv',header=None)
df.columns=['Round', 'Time', 'Numberofplayers', 'totalbet', 'totalwinning', 'onCash']
df['Round']=df['Round'].map(lambda x: x[-1])
df['Time']=df['Time'].map(lambda x: x[len('time: '):])
df['Numberofplayers']=df['Numberofplayers'].map(lambda x: x[len('Numberofplayers: '):])
df['totalbet']=df['totalbet'].map(lambda x: x[len('totalbet: '):])
df['totalwinning']=df['totalwinning'].map(lambda x: x[len('totalwinning: '):])
df['onCash']=df['onCash'].map(lambda x: x[len('onCash: '):])

for i in df.columns:
    if i=='Time':
        continue
    df[i]=df[i].astype(np.float32)


for i in df.where(df['Time']=='0').dropna().index:
    df.drop(i,inplace=True)


for i in df.where(df['Numberofplayers']=='0').dropna().index:
    df.drop(i,inplace=True)


df['hour']=df['Time'].map(lambda x: x.split(':')[0])
df['minutes']=df['Time'].map(lambda x: x.split(':')[1])
df['seconds']=df['Time'].map(lambda x: x.split(':')[2])


df.drop(['Time'],axis=1,inplace=True)


for i in df.columns:
    df[i]=df[i].astype(np.float32)


def resultat_nonverbose(input):
    model_xgboost = XGBRegressor()
    model_xgboost.load_model('xgboost_regression_model.json')


    preds1 = model_xgboost.predict(input)
    bst = lgb.Booster(model_file='lightgbm_regression_model.txt')
    

    preds2 = bst.predict(input)

    

    model = cb.CatBoostRegressor()
    model.load_model('catboost_regression_model.cbm')



    # Make predictions
    preds3 = model.predict(input)

    

    avg_xgboost_lgboost= (preds1.item()+preds2.item())/2

   


    avg_lgboost_catboost= (preds2.item()+preds3.item())/2

    

    return (round(avg_xgboost_lgboost,2)+round(avg_lgboost_catboost,2))/2




df_test=df.drop(['onCash'],axis=1)

print(df.iloc[-2]['onCash'])
resultat_nonverbose([df_test.iloc[-2]])
# Out:
# 3.0
# 2.795

# %%
df_test.iloc[-1]
# Out:
# Round                   4.000000
# Numberofplayers     11377.000000
# totalbet           199873.734375
# totalwinning       630373.312500
# hour                   10.000000
# minutes                20.000000
# seconds                22.000000
# Name: 26143, dtype: float32
